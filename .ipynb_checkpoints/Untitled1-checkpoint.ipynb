# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import copy
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.dummy import DummyClassifier
from sklearn.preprocessing import MinMaxScaler #0과 1사이로 변경
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVR
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn_evaluation import plot
import matplotlib as mpl
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from mlxtend.regressor import StackingRegressor
from mlxtend.data import boston_housing_data
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingClassifier
def R2(y_true,y_pred):    
     r2 = r2_score(y_true, y_pred)
     print('R2:' +str(r2))
     return r2
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
x3_pit = pd.read_csv('data/x3_pit.csv')
x3_pit.drop(['Name','Team','date'],axis=1,inplace=True)

x3_pit_test = pd.read_csv('data/x3_pit2018.csv')
x3_pit_test.drop(['Name','Team','date'],axis=1,inplace=True)

x3_bat = pd.read_csv('data/x3_bat.csv')
x3_bat.drop(['Name','Team','date'],axis=1,inplace=True)

x3_bat_test = pd.read_csv('data/x3_bat2018.csv')
x3_bat_test.drop(['Name','Team','date'],axis=1,inplace=True)

y3_pit = pd.read_csv('data/y3_pit.csv')
y3_pit.drop(['Name','Team','date'],axis=1,inplace=True)

y3_pit_test = pd.read_csv('data/y3_pit2018.csv')
y3_pit_test.drop(['Name','Team','date'],axis=1,inplace=True)

y3_bat = pd.read_csv('data/y3_bat.csv')
y3_bat.drop(['Name','Team','date'],axis=1,inplace=True)

y3_bat_test = pd.read_csv('data/y3_bat2018.csv')
y3_bat_test.drop(['Name','Team','date'],axis=1,inplace=True)

# %%
x3_pit_encoded = x3_pit
x3_bat_encoded = x3_bat
y3_pit_encoded = y3_pit
y3_bat_encoded = y3_bat
x3_pit_test_encoded = x3_pit_test
x3_bat_test_encoded = x3_bat_test
y3_pit_test_encoded = y3_pit_test
y3_bat_test_encoded = y3_bat_test

for x in range(1,6):
    x3_pit_encoded['GA'] = x3_pit_encoded['GA'].replace(x,1)
    x3_bat_encoded['R'] = x3_bat_encoded['R'].replace(x,1)
    y3_pit_encoded['GA'] = y3_pit_encoded['GA'].replace(x,1)
    y3_bat_encoded['R'] = y3_bat_encoded['R'].replace(x,1)
    x3_pit_test_encoded['GA'] = x3_pit_test_encoded['GA'].replace(x,1)
    x3_bat_test_encoded['R'] = x3_bat_test_encoded['R'].replace(x,1)
    y3_pit_test_encoded['GA'] = y3_pit_test_encoded['GA'].replace(x,1)
    y3_bat_test_encoded['R'] = y3_bat_test_encoded['R'].replace(x,1)

# %%
x3_pit_train_X_encoded=x3_pit_encoded.drop(['GA'],axis=1)
x3_pit_train_y_encoded=x3_pit_encoded['GA']
x3_bat_train_X_encoded=x3_bat_encoded.drop(['R'],axis=1)
x3_bat_train_y_encoded=x3_bat_encoded['R']

y3_pit_train_X_encoded=y3_pit_encoded.drop(['GA'],axis=1)
y3_pit_train_y_encoded=y3_pit_encoded['GA']
y3_bat_train_X_encoded=y3_bat_encoded.drop(['R'],axis=1)
y3_bat_train_y_encoded=y3_bat_encoded['R']

x3_pit_test_X_encoded=x3_pit_test_encoded.drop(['GA'],axis=1)
x3_pit_test_y_encoded=x3_pit_test_encoded['GA']
x3_bat_test_X_encoded=x3_bat_test_encoded.drop(['R'],axis=1)
x3_bat_test_y_encoded=x3_bat_test_encoded['R']

y3_pit_test_X_encoded=y3_pit_encoded.drop(['GA'],axis=1)
y3_pit_test_y_encoded=y3_pit_encoded['GA']
y3_bat_test_X_encoded=y3_bat_encoded.drop(['R'],axis=1)
y3_bat_test_y_encoded=y3_bat_encoded['R']

# %%
x3_pit_X_train=x3_pit.drop(['GA'],axis=1)
x3_pit_y_train=x3_pit['GA']
x3_pit_X_test=x3_pit_test.drop(['GA'],axis=1)
x3_pit_y_test=x3_pit_test['GA']
x3_bat_X_train=x3_bat.drop(['R'],axis=1)
x3_bat_y_train=x3_bat['R']
x3_bat_X_test=x3_bat_test.drop(['R'],axis=1)
x3_bat_y_test=x3_bat_test['R']

y3_pit_X_train=y3_pit.drop(['GA'],axis=1)
y3_pit_y_train=y3_pit['GA']
y3_pit_X_test=y3_pit_test.drop(['GA'],axis=1)
y3_pit_y_test=y3_pit_test['GA']
y3_bat_X_train=y3_bat.drop(['R'],axis=1)
y3_bat_y_train=y3_bat['R']
y3_bat_X_test=y3_bat_test.drop(['R'],axis=1)
y3_bat_y_test=y3_bat_test['R']

# %%
minmax = MinMaxScaler()
robust = RobustScaler()
standard = StandardScaler()

# %%
x3_bat_X_train_minmax = minmax.fit_transform(x3_bat_X_train)
x3_bat_X_test_minmax = minmax.fit_transform(x3_bat_X_test)

x3_bat_X_train_robust = robust.fit_transform(x3_bat_X_train)
x3_bat_X_test_robust = robust.fit_transform(x3_bat_X_test)

x3_bat_X_test_standard = standard.fit_transform(x3_bat_X_test)
x3_bat_X_test_standard = standard.fit_transform(x3_bat_X_test)

y3_bat_X_train_minmax = minmax.fit_transform(y3_bat_X_train)
y3_bat_X_test_minmax = minmax.fit_transform(y3_bat_X_test)

y3_bat_X_train_robust = robust.fit_transform(y3_bat_X_train)
y3_bat_X_test_robust = robust.fit_transform(y3_bat_X_test)

y3_bat_X_test_standard = standard.fit_transform(y3_bat_X_test)
y3_bat_X_test_standard = standard.fit_transform(y3_bat_X_test)

# %% [markdown]
# # DNN reg

# %%
B2B1 = tf.feature_column.numeric_column('2B1')
B3B1 = tf.feature_column.numeric_column('3B1')
ERA1 = tf.feature_column.numeric_column('ERA1')
KBB1 = tf.feature_column.numeric_column('K/BB1')
OPS1 = tf.feature_column.numeric_column('OPS1')
WHIP1 = tf.feature_column.numeric_column('WHIP1')
IBB1 = tf.feature_column.numeric_column('IBB1')
BB1 = tf.feature_column.numeric_column('BB1')
HBP1 = tf.feature_column.numeric_column('HBP1')
K1 = tf.feature_column.numeric_column('K1')
GS1 = tf.feature_column.numeric_column('GS1')
W1 = tf.feature_column.numeric_column('W1')
HIT1 = tf.feature_column.numeric_column('HIT1')
SO1 = tf.feature_column.numeric_column('SO1')
CG1 = tf.feature_column.numeric_column('CG1')
INNING1 = tf.feature_column.numeric_column('INNING1')
ER1 = tf.feature_column.numeric_column('ER1')
GP1 = tf.feature_column.numeric_column('GP1')
BF1 = tf.feature_column.numeric_column('BF1')
BA1 = tf.feature_column.numeric_column('BA1')
PA1 = tf.feature_column.numeric_column('PA1')
PITCH1 = tf.feature_column.numeric_column('PITCH1')
L1 = tf.feature_column.numeric_column('L1')
HOLD1 = tf.feature_column.numeric_column('HOLD1')
HR1 = tf.feature_column.numeric_column('HR1')
B2B1 = tf.feature_column.numeric_column('2B1')
B3B1 = tf.feature_column.numeric_column('3B1')
ERA1 = tf.feature_column.numeric_column('ERA1')
KBB1 = tf.feature_column.numeric_column('K/BB1')
OPS1 = tf.feature_column.numeric_column('OPS1')
WHIP1 = tf.feature_column.numeric_column('WHIP1')
IBB1 = tf.feature_column.numeric_column('IBB1')
BB1 = tf.feature_column.numeric_column('BB1')
HBP1 = tf.feature_column.numeric_column('HBP1')
K1 = tf.feature_column.numeric_column('K1')
GS1 = tf.feature_column.numeric_column('GS1')
W1 = tf.feature_column.numeric_column('W1')
HIT1 = tf.feature_column.numeric_column('HIT1')
SO1 = tf.feature_column.numeric_column('SO1')
CG1 = tf.feature_column.numeric_column('CG1')
INNING1 = tf.feature_column.numeric_column('INNING1')
ER1 = tf.feature_column.numeric_column('ER1')
GP1 = tf.feature_column.numeric_column('GP1')
BF1 = tf.feature_column.numeric_column('BF1')
BA1 = tf.feature_column.numeric_column('BA1')
PA1 = tf.feature_column.numeric_column('PA1')
PITCH1 = tf.feature_column.numeric_column('PITCH1')
L1 = tf.feature_column.numeric_column('L1')
HOLD1 = tf.feature_column.numeric_column('HOLD1')
HR1 = tf.feature_column.numeric_column('HR1')

B2B2 = tf.feature_column.numeric_column('2B2')
B3B2 = tf.feature_column.numeric_column('3B2')
ERA2 = tf.feature_column.numeric_column('ERA2')
KBB2 = tf.feature_column.numeric_column('K/BB2')
OPS2 = tf.feature_column.numeric_column('OPS2')
WHIP2 = tf.feature_column.numeric_column('WHIP2')
IBB2 = tf.feature_column.numeric_column('IBB2')
BB2 = tf.feature_column.numeric_column('BB2')
HBP2 = tf.feature_column.numeric_column('HBP2')
K2 = tf.feature_column.numeric_column('K2')
GS2 = tf.feature_column.numeric_column('GS2')
W2 = tf.feature_column.numeric_column('W2')
HIT2 = tf.feature_column.numeric_column('HIT2')
SO2 = tf.feature_column.numeric_column('SO2')
CG2 = tf.feature_column.numeric_column('CG2')
INNING2 = tf.feature_column.numeric_column('INNING2')
ER2 = tf.feature_column.numeric_column('ER2')
GP2 = tf.feature_column.numeric_column('GP2')
BF2 = tf.feature_column.numeric_column('BF2')
BA2 = tf.feature_column.numeric_column('BA2')
PA2 = tf.feature_column.numeric_column('PA2')
PITCH2 = tf.feature_column.numeric_column('PITCH2')
L2 = tf.feature_column.numeric_column('L2')
HOLD2 = tf.feature_column.numeric_column('HOLD2')
HR2 = tf.feature_column.numeric_column('HR2')

B2B3 = tf.feature_column.numeric_column('2B3')
B3B3 = tf.feature_column.numeric_column('3B3')
ERA3 = tf.feature_column.numeric_column('ERA3')
KBB3 = tf.feature_column.numeric_column('K/BB3')
OPS3 = tf.feature_column.numeric_column('OPS3')
WHIP3 = tf.feature_column.numeric_column('WHIP3')
IBB3 = tf.feature_column.numeric_column('IBB3')
BB3 = tf.feature_column.numeric_column('BB3')
HBP3 = tf.feature_column.numeric_column('HBP3')
K3 = tf.feature_column.numeric_column('K3')
GS3 = tf.feature_column.numeric_column('GS3')
W3 = tf.feature_column.numeric_column('W3')
HIT3 = tf.feature_column.numeric_column('HIT3')
SO3 = tf.feature_column.numeric_column('SO3')
CG3 = tf.feature_column.numeric_column('CG3')
INNING3 = tf.feature_column.numeric_column('INNING3')
ER3 = tf.feature_column.numeric_column('ER3')
GP3 = tf.feature_column.numeric_column('GP3')
BF3 = tf.feature_column.numeric_column('BF3')
BA3 = tf.feature_column.numeric_column('BA3')
PA3 = tf.feature_column.numeric_column('PA3')
PITCH3 = tf.feature_column.numeric_column('PITCH3')
L3 = tf.feature_column.numeric_column('L3')
HOLD3 = tf.feature_column.numeric_column('HOLD3')
HR3 = tf.feature_column.numeric_column('HR3')

# ----------------------------------------------------------------------------
feat_cols = [B2B1, B3B1, ERA1, KBB1, OPS1, WHIP1, IBB1, BB1, HBP1, K1, GS1, W1, HIT1, SO1, CG1, INNING1, ER1, GP1, BF1, BA1, PA1, PITCH1, L1, HOLD1, HR1,B2B2, B3B2, ERA2, KBB2, OPS2, WHIP2, IBB2, BB2, HBP2, K2, GS2, W2, HIT2, SO2, CG2, INNING2, ER2, GP2, BF2, BA2, PA2, PITCH2, L2, HOLD2, HR2,B2B3, B3B3, ERA3, KBB3, OPS3, WHIP3, IBB3, BB3, HBP3, K3, GS3, W3, HIT3, SO3, CG3, INNING3, ER3, GP3, BF3, BA3, PA3, PITCH3, L3, HOLD3, HR3]
input_func = tf.estimator.inputs.pandas_input_fn(x=x3_pit_X_train,y=x3_pit_y_train,shuffle=True)

model = tf.estimator.DNNRegressor(hidden_units=[20,20,20],feature_columns=feat_cols)
model.train(input_fn=input_func,steps=1000)

predict_input_func = tf.estimator.inputs.pandas_input_fn(x=x3_pit_X_test,y=x3_pit_y_test,batch_size=128,num_epochs=1,shuffle=False)

pred_gen = model.predict(predict_input_func)

predictions = list(pred_gen)
final_preds = []
for pred in predictions:
    final_preds.append(pred['predictions'])

r2_score(x3_pit_y_test,final_preds)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sn/hzp1yx0d60v61zwrm2rq2hx40000gn/T/tmpqk0p6gr8
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sn/hzp1yx0d60v61zwrm2rq2hx40000gn/T/tmpqk0p6gr8', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x104a86b70>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# ...

# %%
feat_cols = [B2B1, B3B1, ERA1, KBB1, OPS1, WHIP1, IBB1, BB1, HBP1, K1, GS1, W1, HIT1, SO1, CG1, INNING1, ER1, GP1, BF1, BA1, PA1, PITCH1, L1, HOLD1, HR1,B2B2, B3B2, ERA2, KBB2, OPS2, WHIP2, IBB2, BB2, HBP2, K2, GS2, W2, HIT2, SO2, CG2, INNING2, ER2, GP2, BF2, BA2, PA2, PITCH2, L2, HOLD2, HR2,B2B3, B3B3, ERA3, KBB3, OPS3, WHIP3, IBB3, BB3, HBP3, K3, GS3, W3, HIT3, SO3, CG3, INNING3, ER3, GP3, BF3, BA3, PA3, PITCH3, L3, HOLD3, HR3]
input_func = tf.estimator.inputs.pandas_input_fn(x=x3_pit_X_train,y=x3_pit_y_train,shuffle=True)

model = tf.estimator.DNNRegressor(hidden_units=[20,20,20],feature_columns=feat_cols)
model.train(input_fn=input_func,steps=1000)

predict_input_func = tf.estimator.inputs.pandas_input_fn(x=x3_pit_X_test,y=x3_pit_y_test,batch_size=128,num_epochs=1,shuffle=False)

pred_gen = model.predict(predict_input_func)

predictions = list(pred_gen)
final_preds = []
for pred in predictions:
    final_preds.append(pred['predictions'])

r2_score(x3_pit_y_test,final_preds)

# %%
B2B1 = tf.feature_column.numeric_column('2B1')
B3B1 = tf.feature_column.numeric_column('3B1')
ERA1 = tf.feature_column.numeric_column('ERA1')
KBB1 = tf.feature_column.numeric_column('K/BB1')
OPS1 = tf.feature_column.numeric_column('OPS1')
WHIP1 = tf.feature_column.numeric_column('WHIP1')
IBB1 = tf.feature_column.numeric_column('IBB1')
BB1 = tf.feature_column.numeric_column('BB1')
HBP1 = tf.feature_column.numeric_column('HBP1')
K1 = tf.feature_column.numeric_column('K1')
GS1 = tf.feature_column.numeric_column('GS1')
W1 = tf.feature_column.numeric_column('W1')
HIT1 = tf.feature_column.numeric_column('HIT1')
SO1 = tf.feature_column.numeric_column('SO1')
CG1 = tf.feature_column.numeric_column('CG1')
INNING1 = tf.feature_column.numeric_column('INNING1')
ER1 = tf.feature_column.numeric_column('ER1')
GP1 = tf.feature_column.numeric_column('GP1')
BF1 = tf.feature_column.numeric_column('BF1')
BA1 = tf.feature_column.numeric_column('BA1')
PA1 = tf.feature_column.numeric_column('PA1')
PITCH1 = tf.feature_column.numeric_column('PITCH1')
L1 = tf.feature_column.numeric_column('L1')
HOLD1 = tf.feature_column.numeric_column('HOLD1')
HR1 = tf.feature_column.numeric_column('HR1')
B2B1 = tf.feature_column.numeric_column('2B1')
B3B1 = tf.feature_column.numeric_column('3B1')
ERA1 = tf.feature_column.numeric_column('ERA1')
KBB1 = tf.feature_column.numeric_column('K/BB1')
OPS1 = tf.feature_column.numeric_column('OPS1')
WHIP1 = tf.feature_column.numeric_column('WHIP1')
IBB1 = tf.feature_column.numeric_column('IBB1')
BB1 = tf.feature_column.numeric_column('BB1')
HBP1 = tf.feature_column.numeric_column('HBP1')
K1 = tf.feature_column.numeric_column('K1')
GS1 = tf.feature_column.numeric_column('GS1')
W1 = tf.feature_column.numeric_column('W1')
HIT1 = tf.feature_column.numeric_column('HIT1')
SO1 = tf.feature_column.numeric_column('SO1')
CG1 = tf.feature_column.numeric_column('CG1')
INNING1 = tf.feature_column.numeric_column('INNING1')
ER1 = tf.feature_column.numeric_column('ER1')
GP1 = tf.feature_column.numeric_column('GP1')
BF1 = tf.feature_column.numeric_column('BF1')
BA1 = tf.feature_column.numeric_column('BA1')
PA1 = tf.feature_column.numeric_column('PA1')
PITCH1 = tf.feature_column.numeric_column('PITCH1')
L1 = tf.feature_column.numeric_column('L1')
HOLD1 = tf.feature_column.numeric_column('HOLD1')
HR1 = tf.feature_column.numeric_column('HR1')

B2B2 = tf.feature_column.numeric_column('2B2')
B3B2 = tf.feature_column.numeric_column('3B2')
ERA2 = tf.feature_column.numeric_column('ERA2')
KBB2 = tf.feature_column.numeric_column('K/BB2')
OPS2 = tf.feature_column.numeric_column('OPS2')
WHIP2 = tf.feature_column.numeric_column('WHIP2')
IBB2 = tf.feature_column.numeric_column('IBB2')
BB2 = tf.feature_column.numeric_column('BB2')
HBP2 = tf.feature_column.numeric_column('HBP2')
K2 = tf.feature_column.numeric_column('K2')
GS2 = tf.feature_column.numeric_column('GS2')
W2 = tf.feature_column.numeric_column('W2')
HIT2 = tf.feature_column.numeric_column('HIT2')
SO2 = tf.feature_column.numeric_column('SO2')
CG2 = tf.feature_column.numeric_column('CG2')
INNING2 = tf.feature_column.numeric_column('INNING2')
ER2 = tf.feature_column.numeric_column('ER2')
GP2 = tf.feature_column.numeric_column('GP2')
BF2 = tf.feature_column.numeric_column('BF2')
BA2 = tf.feature_column.numeric_column('BA2')
PA2 = tf.feature_column.numeric_column('PA2')
PITCH2 = tf.feature_column.numeric_column('PITCH2')
L2 = tf.feature_column.numeric_column('L2')
HOLD2 = tf.feature_column.numeric_column('HOLD2')
HR2 = tf.feature_column.numeric_column('HR2')

B2B3 = tf.feature_column.numeric_column('2B3')
B3B3 = tf.feature_column.numeric_column('3B3')
ERA3 = tf.feature_column.numeric_column('ERA3')
KBB3 = tf.feature_column.numeric_column('K/BB3')
OPS3 = tf.feature_column.numeric_column('OPS3')
WHIP3 = tf.feature_column.numeric_column('WHIP3')
IBB3 = tf.feature_column.numeric_column('IBB3')
BB3 = tf.feature_column.numeric_column('BB3')
HBP3 = tf.feature_column.numeric_column('HBP3')
K3 = tf.feature_column.numeric_column('K3')
GS3 = tf.feature_column.numeric_column('GS3')
W3 = tf.feature_column.numeric_column('W3')
HIT3 = tf.feature_column.numeric_column('HIT3')
SO3 = tf.feature_column.numeric_column('SO3')
CG3 = tf.feature_column.numeric_column('CG3')
INNING3 = tf.feature_column.numeric_column('INNING3')
ER3 = tf.feature_column.numeric_column('ER3')
GP3 = tf.feature_column.numeric_column('GP3')
BF3 = tf.feature_column.numeric_column('BF3')
BA3 = tf.feature_column.numeric_column('BA3')
PA3 = tf.feature_column.numeric_column('PA3')
PITCH3 = tf.feature_column.numeric_column('PITCH3')
L3 = tf.feature_column.numeric_column('L3')
HOLD3 = tf.feature_column.numeric_column('HOLD3')
HR3 = tf.feature_column.numeric_column('HR3')

# ----------------------------------------------------------------------------
feat_cols = [B2B1, B3B1, ERA1, KBB1, OPS1, WHIP1, IBB1, BB1, HBP1, K1, GS1, W1, HIT1, SO1, CG1, INNING1, ER1, GP1, BF1, BA1, PA1, PITCH1, L1, HOLD1, HR1,B2B2, B3B2, ERA2, KBB2, OPS2, WHIP2, IBB2, BB2, HBP2, K2, GS2, W2, HIT2, SO2, CG2, INNING2, ER2, GP2, BF2, BA2, PA2, PITCH2, L2, HOLD2, HR2,B2B3, B3B3, ERA3, KBB3, OPS3, WHIP3, IBB3, BB3, HBP3, K3, GS3, W3, HIT3, SO3, CG3, INNING3, ER3, GP3, BF3, BA3, PA3, PITCH3, L3, HOLD3, HR3]
input_func = tf.estimator.inputs.pandas_input_fn(x=x3_pit_train_X_encoded,y=x3_pit_train_y_encoded,shuffle=True)

model = tf.estimator.Classifier(hidden_units=[20,20,20],feature_columns=feat_cols)
model.train(input_fn=input_func,steps=1000)

predict_input_func = tf.estimator.inputs.pandas_input_fn(x=x3_pit_test_X_encoded,y=x3_pit_test_y_encoded,batch_size=128,num_epochs=1,shuffle=False)

pred_gen = model.predict(predict_input_func)

predictions = list(pred_gen)
final_preds = []
for pred in predictions:
    final_preds.append(pred['predictions'])

# %% [markdown]
# def pred_clf_all(X_train, X_test, y_train, y_test)
#     knn = KNeighborsClassifier()
#     knn.fit(x_data2_encoded,y_data2_encoded)
#     print('KNN train : ' + str(knn.score(X_train,y_train)))
#     print('KNN test : '+str(knn.score(X_test,y_test)))
#     knn_pred = pd.DataFrame(knn.predict(X_test))
#
#     tree = DecisionTreeClassifier()
#     knn.fit(x_data2_encoded,y_data2_encoded)
#     print('KNN train : ' + str(knn.score(X_train,y_train)))
#     print('KNN test : '+str(knn.score(X_test,y_test)))
#     knn_pred = pd.DataFrame(knn.predict(X_test))

# %%
def pred_clf_all(X_train, y_train, X_test, y_test):
    grad_clf = GradientBoostingClassifier()
    grad_clf.fit(X_train, y_train)
    grad_clf_pred = pd.DataFrame(grad_clf.predict(X_test))
    grad_clf_pred.to_csv('x3_bat_grad_clf.csv')

    rand_clf = RandomForestClassifier()
    rand_clf.fit(X_train, y_train)
    rand_clf_pred = pd.DataFrame(rand_clf.predict(X_test))
    rand_clf_pred.to_csv('x3_bat_rand_clf.csv')
    
    svc = svm.SVC()
    svc.fit(X_train, y_train)
    svc_pred = pd.DataFrame(svc.predict(X_test))
    svc_pred.to_csv('x3_bat_svm_clf.csv')

# %%
pred_clf_all(x3_bat_train_X_encoded, x3_bat_train_y_encoded, x3_bat_test_X_encoded, x3_bat_test_y_encoded)

# %%
def pred_clf_all(X_train, y_train, X_test, y_test):
    grad_clf = GradientBoostingClassifier()
    grad_clf.fit(X_train, y_train)
    grad_clf_pred = pd.DataFrame(grad_clf.predict(X_test))
    grad_clf_pred.to_csv('x3_bat_grad_clf.csv')

    rand_clf = RandomForestClassifier()
    rand_clf.fit(X_train, y_train)
    rand_clf_pred = pd.DataFrame(rand_clf.predict(X_test))
    rand_clf_pred.to_csv('x3_bat_rand_clf.csv')
    
    svc = svm.SVC()
    svc.fit(X_train, y_train)
    svc_pred = pd.DataFrame(svc.predict(X_test))
    svc_pred.to_csv('x3_bat_svm_clf.csv')

# %%
pred_clf_all(x3_bat_train_X_encoded, x3_bat_train_y_encoded, x3_bat_test_X_encoded, x3_bat_test_y_encoded)

# %%
def pred_reg_all(X_train, y_train, X_test, y_test):
    svr_poly = SVR(kernel='poly')
    svr_poly.fit(X_train, y_train)
    print('SVR(poly) Test Dataset R square : ' +str(round(svr_poly.score(X_test,y_test),4)))
    svr_poly_pred = pd.DataFrame(svr_poly.predict(X_test))
    
    svr_rbf = SVR(kernel='rbf')
    svr_rbf.fit(X_train, y_train)
    print('SVR(rbf) Test Dataset R square : ' +str(round(svr_rbf.score(X_test,y_test),4)))
    svr_rbf_pred = pd.DataFrame(svr_rbf.predict(X_test))
    
    svr_sigmoid = SVR(kernel ='sigmoid')
    svr_sigmoid.fit(X_train, y_train)
    print('SVR(sigmoid) Test Dataset R Square : '+str(round(svr_sigmoid.score(X_test, y_test),4)))
    svr_sigmoid_pred = pd.DataFrame(svr_sigmoid.predict(X_test))
    
    svr_pred = SVR(kernel ='precomputed')
    svr_prec.fit(X_train, y_train)
    print('SVR(precomputed) Test Dataset R Square : '+str(round(svr_prec.score(X_test, y_test),4)))
    svr_prec_pred = pd.DataFrame(svr_prec.predict(X_test))

# %%
pred_reg_all(x3_bat_X_train, x3_bat_y_train, x3_bat_X_test, x3_bat_y_test)
svr_poly_regr_pred.to_csv('x3_bat_svr_poly_regr.csv')
svr_rbf_regr_pred.to_csv('x3_bat_svr_rbf_regr.csv')
svr_sigmoid_regr_pred.to_csv('x3_bat_svr_sigmoid_regr.csv')
svr_prec_regr_pred.to_csv('x3_bat_svr_prec_regr.csv')

# %%
def pred_reg_all_2(X_train, y_train, X_test, y_test):
    rand_regr = RandomForestRegressor()
    rand_regr.fit(X_train, y_train)
#     rand_regr_pred = pd.DataFrame(rand_regr.predict(x_bat))
    print('Random Forest Regressor Test Dataset R Sqare : ' + str(round(rand_regr.score(X_train,y_train),4)))
    rand_regr_pred = pd.DataFrame(rand_regr.predict(X_test))
    rand_regr_pred.to_csv('x3_bat_rand_regr.csv')
    
    grad_regr = GradientBoostingRegressor()
    grad_regr.fit(X_train, y_train)
    print('Gradient Boosting Regressor Test Dataset R Sqare : ' + str(round(grad_regr.score(X_train,y_train),4)))
    # grad_regr.pred = pd.DataFrame(grad_regr.predict(x_bat))
    grad_regr_pred = pd.DataFrame(grad_regr.predict(X_test))
    grad_regr_pred.to_csv('x3_bat_grad_regr.csv')

    
#     ela_regr = ElasticNet()
#     ela_regr.fit(X_train, y_train)
#     print('Elastic Boosting Regressor Test Dataset R Sqare : ' + str(round(ela_regr.score(X_train,y_train),4)))
#     ela_regr_pred = pd.DataFrame(ela_regr.predict(X_test))
# ela_regr_pred.to_csv('x3_bat_ela_regr.csv')
    

#     lr = LinearRegression()
#     svr_lin = SVR(kernel='linear')
#     ridge = Ridge(random_state=1)
#     svr_rbf = SVR(kernel='rbf')

#     stack_regr = StackingRegressor(regressors=[svr_lin, lr, ridge], 
#                            meta_regressor=svr_rbf)

#     stack_regr.fit(X_train, y_train)
#     stack_regr_pred = pd.DataFrame(stack_regr.predict(X_test))
# stack_regr_pred.to_csv('x3_bat_stack_regr.csv')

# %%
pred_reg_all_2(x3_bat_X_train, x3_bat_y_train, x3_bat_X_test, x3_bat_y_test)
# Out:
# Random Forest Regressor Test Dataset R Sqare : 0.7991
# Gradient Boosting Regressor Test Dataset R Sqare : 0.0195

# %%
def pred_reg_all_2(X_train, y_train, X_test, y_test):
    rand_regr = RandomForestRegressor()
    rand_regr.fit(X_train, y_train)
#     rand_regr_pred = pd.DataFrame(rand_regr.predict(x_bat))
    print('Random Forest Regressor Test Dataset R Sqare : ' + str(round(rand_regr.score(X_train,y_train),4)))
    rand_regr_pred = pd.DataFrame(rand_regr.predict(X_test))
    rand_regr_pred.to_csv('x3_pit_rand_regr.csv')
    
    grad_regr = GradientBoostingRegressor()
    grad_regr.fit(X_train, y_train)
    print('Gradient Boosting Regressor Test Dataset R Sqare : ' + str(round(grad_regr.score(X_train,y_train),4)))
    # grad_regr.pred = pd.DataFrame(grad_regr.predict(x_bat))
    grad_regr_pred = pd.DataFrame(grad_regr.predict(X_test))
    grad_regr_pred.to_csv('x3_pit_grad_regr.csv')

    
#     ela_regr = ElasticNet()
#     ela_regr.fit(X_train, y_train)
#     print('Elastic Boosting Regressor Test Dataset R Sqare : ' + str(round(ela_regr.score(X_train,y_train),4)))
#     ela_regr_pred = pd.DataFrame(ela_regr.predict(X_test))
# ela_regr_pred.to_csv('x3_bat_ela_regr.csv')
    

#     lr = LinearRegression()
#     svr_lin = SVR(kernel='linear')
#     ridge = Ridge(random_state=1)
#     svr_rbf = SVR(kernel='rbf')

#     stack_regr = StackingRegressor(regressors=[svr_lin, lr, ridge], 
#                            meta_regressor=svr_rbf)

#     stack_regr.fit(X_train, y_train)
#     stack_regr_pred = pd.DataFrame(stack_regr.predict(X_test))
# stack_regr_pred.to_csv('x3_bat_stack_regr.csv')

# %%
pred_reg_all_2(x3_pit_X_train, x3_pit_y_train, x3_pit_X_test, x3_pit_y_test)
# Out:
# Random Forest Regressor Test Dataset R Sqare : 0.789
# Gradient Boosting Regressor Test Dataset R Sqare : 0.0855

# %%
def pred_reg_all_2(X_train, y_train, X_test, y_test):
    rand_regr = RandomForestRegressor()
    rand_regr.fit(X_train, y_train)
#     rand_regr_pred = pd.DataFrame(rand_regr.predict(x_bat))
    print('Random Forest Regressor Test Dataset R Sqare : ' + str(round(rand_regr.score(X_train,y_train),4)))
    rand_regr_pred = pd.DataFrame(rand_regr.predict(X_test))
    rand_regr_pred.to_csv('y3_pit_rand_regr.csv')
    
    grad_regr = GradientBoostingRegressor()
    grad_regr.fit(X_train, y_train)
    print('Gradient Boosting Regressor Test Dataset R Sqare : ' + str(round(grad_regr.score(X_train,y_train),4)))
    # grad_regr.pred = pd.DataFrame(grad_regr.predict(x_bat))
    grad_regr_pred = pd.DataFrame(grad_regr.predict(X_test))
    grad_regr_pred.to_csv('y3_pit_grad_regr.csv')

    
#     ela_regr = ElasticNet()
#     ela_regr.fit(X_train, y_train)
#     print('Elastic Boosting Regressor Test Dataset R Sqare : ' + str(round(ela_regr.score(X_train,y_train),4)))
#     ela_regr_pred = pd.DataFrame(ela_regr.predict(X_test))
# ela_regr_pred.to_csv('x3_bat_ela_regr.csv')
    

#     lr = LinearRegression()
#     svr_lin = SVR(kernel='linear')
#     ridge = Ridge(random_state=1)
#     svr_rbf = SVR(kernel='rbf')

#     stack_regr = StackingRegressor(regressors=[svr_lin, lr, ridge], 
#                            meta_regressor=svr_rbf)

#     stack_regr.fit(X_train, y_train)
#     stack_regr_pred = pd.DataFrame(stack_regr.predict(X_test))
# stack_regr_pred.to_csv('x3_bat_stack_regr.csv')

# %%
pred_reg_all_2(y3_pit_X_train, y3_pit_y_train, y3_pit_X_test, y3_pit_y_test)
# Out:
# Random Forest Regressor Test Dataset R Sqare : 0.2194
# Gradient Boosting Regressor Test Dataset R Sqare : 0.133

# %%
def pred_reg_all_2(X_train, y_train, X_test, y_test):
    rand_regr = RandomForestRegressor()
    rand_regr.fit(X_train, y_train)
#     rand_regr_pred = pd.DataFrame(rand_regr.predict(x_bat))
    print('Random Forest Regressor Test Dataset R Sqare : ' + str(round(rand_regr.score(X_train,y_train),4)))
    rand_regr_pred = pd.DataFrame(rand_regr.predict(X_test))
    rand_regr_pred.to_csv('y3_bat_rand_regr.csv')
    
    grad_regr = GradientBoostingRegressor()
    grad_regr.fit(X_train, y_train)
    print('Gradient Boosting Regressor Test Dataset R Sqare : ' + str(round(grad_regr.score(X_train,y_train),4)))
    # grad_regr.pred = pd.DataFrame(grad_regr.predict(x_bat))
    grad_regr_pred = pd.DataFrame(grad_regr.predict(X_test))
    grad_regr_pred.to_csv('y3_bat_grad_regr.csv')

    
#     ela_regr = ElasticNet()
#     ela_regr.fit(X_train, y_train)
#     print('Elastic Boosting Regressor Test Dataset R Sqare : ' + str(round(ela_regr.score(X_train,y_train),4)))
#     ela_regr_pred = pd.DataFrame(ela_regr.predict(X_test))
# ela_regr_pred.to_csv('x3_bat_ela_regr.csv')
    

#     lr = LinearRegression()
#     svr_lin = SVR(kernel='linear')
#     ridge = Ridge(random_state=1)
#     svr_rbf = SVR(kernel='rbf')

#     stack_regr = StackingRegressor(regressors=[svr_lin, lr, ridge], 
#                            meta_regressor=svr_rbf)

#     stack_regr.fit(X_train, y_train)
#     stack_regr_pred = pd.DataFrame(stack_regr.predict(X_test))
# stack_regr_pred.to_csv('x3_bat_stack_regr.csv')

# %%
pred_reg_all_2(y3_bat_X_train, y3_bat_y_train, y3_bat_X_test, y3_bat_y_test)
# Out:
# Random Forest Regressor Test Dataset R Sqare : 0.0045
# Gradient Boosting Regressor Test Dataset R Sqare : 0.0033

# %%
rand_regr_pred.to_csv('y3_bat_rand_regr.csv')
grad_regr_pred.to_csv('y3_bat_grad_regr.csv')
# ela_regr_pred.to_csv('y3_bat_ela_regr.csv')
# stack_regr_pred.to_csv('y3_bat_stack_regr.csv')

# %%
# Evaluate and visualize the fit

print("Mean Squared Error: %.4f"
      % np.mean((stregr.predict(X) - y) ** 2))
print('Variance Score: %.4f' % stregr.score(X, y))

with plt.style.context(('seaborn-whitegrid')):
    plt.scatter(x3_bat_X_train, x3_bat_y_train, c='lightgray')
    plt.plot(x3_bat_X_test, stack_regr.predict(x3_bat_X_test), c='darkgreen', lw=2)

plt.show()
